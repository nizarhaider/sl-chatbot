# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/openslr_sinhala/metadata.csv')

# %%
df['source'].unique()
# Out:
# <ArrowStringArray>
# ['sin_2241', 'sin_2282', 'sin_3531', 'sin_3688', 'sin_3976', 'sin_4191',
#  'sin_4499', 'sin_5681', 'sin_6314', 'sin_6897', 'sin_7183', 'sin_9228']
# Length: 12, dtype: str
